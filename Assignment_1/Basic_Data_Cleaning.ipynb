# %%
import pandas as pd

# %%
df = pd.read_csv("casual-shoes.csv")

# %%
df.head()
# Out:
#    product_id            title                        product_description  \
# 0    20129438         Skechers                 Men Blue Textured Sneakers
# 1    18506050             Bata  Women Black Woven Design Slip-On Sneakers
# 2    21739362         Prolific   Men Printed LightWeight Mid Top Sneakers
# 3    21903832  U.S. Polo Assn.                  Women Perforated Sneakers
# 4    21651940       HIGHLANDER            Men Black Woven Design Sneakers
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             11        12999.0      30.0  "₹7,799.00"      INR
# 1     4.4             86         1199.0      55.0    "₹539.00"      INR
# 2     3.9              8         2660.0      71.0    "₹771.00"      INR
# 3     4.1             16         4299.0      25.0  "₹3,224.00"      INR
# 4     3.4             25         1898.0      55.0    "₹569.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.shape
# Out:
# (23, 24)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
df.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price             float64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %%
df.tail()
# Out:
#     product_id            title  \
# 18    17312144           Clarks
# 19    17350218           Delize
# 20    17361518         Buckaroo
# 21    16284648      Crew STREET
# 22    19103830  PUMA Motorsport
#
#                                   product_description  rating  ratings_count  \
# 18               Men Black Perforations Nubuck Derbys     3.7              3
# 19              Men Black Leather High-Top Flat Boots     0.0              0
# 20             Men Tan Brown Solid Leather Flat Boots     0.0              0
# 21      Women Sea Green Woven Design Slip-On Sneakers     4.1             41
# 22  Unisex Black Perforations BMW MMS Neo Cat Regu...     4.5            157
#
#     initial_price  discount  final_price currency  \
# 18        10999.0      35.0  "₹7,149.00"      INR
# 19        13999.0      68.0  "₹4,479.00"      INR
# 20         4999.0      25.0  "₹3,749.00"      INR
# 21         3099.0      55.0  "₹1,394.00"      INR
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              23 non-null     int64
#  1   title                   23 non-null     object
#  2   product_description     23 non-null     object
#  3   rating                  23 non-null     float64
#  4   ratings_count           23 non-null     int64
#  5   initial_price           23 non-null     float64
#  6   discount                22 non-null     float64
#  7   final_price             23 non-null     object
#  8   currency                23 non-null     object
#  9   images                  23 non-null     object
#  10  delivery_options        23 non-null     object
#  11  product_details         23 non-null     object
#  12  breadcrumbs             23 non-null     object
#  13  product_specifications  23 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# product_id                 0
# title                      0
# product_description        0
# rating                     0
# ratings_count              0
# initial_price              0
# discount                   1
# final_price                0
# currency                   0
# images                     0
# delivery_options           0
# product_details            0
# breadcrumbs                0
# product_specifications     0
# amount_of_stars            0
# what_customers_said       12
# seller_name                3
# sizes                      0
# videos                    19
# seller_information         3
# variations                11
# best_offer                 0
# more_offers                0
# category                   0
# dtype: int64

# %%
df.fillna("Not Available", inplace=True)
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_27180\3513367982.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Available' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("Not Available", inplace=True)

# %%
df.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# videos                    0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (23, 24)

# %%
df[df["rating"] > 4]
# Out:
#     product_id            title  \
# 1     18506050             Bata
# 3     21903832  U.S. Polo Assn.
# 5     21321784      San Frissco
# 8     21497770             Puma
# 13    18489168             TOMS
# 16    17312062           Clarks
# 21    16284648      Crew STREET
# 22    19103830  PUMA Motorsport
#
#                                   product_description  rating  ratings_count  \
# 1           Women Black Woven Design Slip-On Sneakers     4.4             86
# 3                           Women Perforated Sneakers     4.1             16
# 5                         Men  Colourblocked Sneakers     4.3              6
# 8                                        Men Sneakers     4.1            111
# 13  Women Red Solid Alpargata Canvas Slip-On Sneakers     4.3              6
# 16                      Men Blue Nubuck Penny Loafers     4.6             31
# 21      Women Sea Green Woven Design Slip-On Sneakers     4.1             41
# ...

# %%
df[["title", "rating", "initial_price"]]
# Out:
#                         title  rating  initial_price
# 0                    Skechers     3.8        12999.0
# 1                        Bata     4.4         1199.0
# 2                    Prolific     3.9         2660.0
# 3             U.S. Polo Assn.     4.1         4299.0
# 4                  HIGHLANDER     3.4         1898.0
# 5                 San Frissco     4.3         5995.0
# 6                  Eego Italy     0.0         2999.0
# 7                     MOZAFIA     4.0         1999.0
# 8                        Puma     4.1         4999.0
# 9       HRX by Hrithik Roshan     3.9         3299.0
# 10                      WROGN     3.7         3599.0
# 11                     FAUSTO     3.2          999.0
# 12                     FAUSTO     2.5         1299.0
# 13                       TOMS     4.3         4999.0
# 14  Fame Forever by Lifestyle     0.0          999.0
# 15                 HIGHLANDER     3.9         2198.0
# 16                     Clarks     4.6         6999.0
# ...

# %%
df["total_amount"] = df["initial_price"] * df["ratings_count"]

# %%
df[["title","initial_price","ratings_count","total_amount"]].head()
# Out:
#              title  initial_price  ratings_count  total_amount
# 0         Skechers        12999.0             11      142989.0
# 1             Bata         1199.0             86      103114.0
# 2         Prolific         2660.0              8       21280.0
# 3  U.S. Polo Assn.         4299.0             16       68784.0
# 4       HIGHLANDER         1898.0             25       47450.0

# %%
df.to_csv("cleaned_casual_shoes.csv", index=False)
